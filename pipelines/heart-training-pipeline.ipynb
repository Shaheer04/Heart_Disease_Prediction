# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/heart-preprocessing-pipeline/preprocessing_pipeline_new.pkl

# %%
# !pip install hopsworks
# Out:
# Collecting hopsworks
#   Downloading hopsworks-3.7.0.tar.gz (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 789.9 kB/s eta 0:00:00 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting hsfs<3.8.0,>=3.7.0 (from hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading hsfs-3.7.6.tar.gz (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.8/249.8 kB 3.1 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting hsml<3.8.0,>=3.7.0 (from hopsworks)
#   Downloading hsml-3.7.1.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyhumps==1.6.1 (from hopsworks)
#   Downloading pyhumps-1.6.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from hopsworks) (2.32.3)
# Collecting furl (from hopsworks)
#   Downloading furl-2.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.10/site-packages (from hopsworks) (1.26.100)
# Collecting pyjks (from hopsworks)
#   Downloading pyjks-20.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mock (from hopsworks)
#   Downloading mock-5.1.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from hopsworks) (4.66.4)
# Collecting pandas<2.2.0 (from hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy<2 in /opt/conda/lib/python3.10/site-packages (from hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.26.4)
# Collecting avro==1.11.3 (from hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading avro-1.11.3.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 6.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sqlalchemy<=1.4.48 (from hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading SQLAlchemy-1.4.48-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting PyMySQL[rsa] (from hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Collecting great_expectations==0.18.12 (from hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading great_expectations-0.18.12-py3-none-any.whl.metadata (8.9 kB)
# Collecting tzlocal (from hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2024.3.1)
# Requirement already satisfied: retrying in /opt/conda/lib/python3.10/site-packages (from hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.3.3)
# Collecting aiomysql (from hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading aiomysql-0.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting opensearch-py<=2.4.2,>=1.1.0 (from hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading opensearch_py-2.4.2-py2.py3-none-any.whl.metadata (6.8 kB)
# Collecting altair<5.0.0,>=4.2.1 (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading altair-4.2.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: Click>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (8.1.7)
# Requirement already satisfied: colorama>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.4.6)
# Requirement already satisfied: cryptography>=3.2 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (41.0.7)
# Requirement already satisfied: Ipython>=7.16.3 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (8.20.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (7.7.1)
# Requirement already satisfied: jinja2>=2.10 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (3.1.2)
# Requirement already satisfied: jsonpatch>=1.22 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.33)
# Requirement already satisfied: jsonschema>=2.5.1 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (4.20.0)
# Collecting makefun<2,>=1.7.0 (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading makefun-1.15.2-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (3.21.2)
# Requirement already satisfied: mistune>=0.8.4 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.8.4)
# Requirement already satisfied: nbformat>=5.0 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (5.9.2)
# Requirement already satisfied: notebook>=6.4.10 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (6.5.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (21.3)
# Requirement already satisfied: pydantic>=1.9.2 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2.5.3)
# Requirement already satisfied: pyparsing>=2.4 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2021.3 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2023.3.post1)
# Collecting ruamel.yaml<0.17.18,>=0.16 (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading ruamel.yaml-0.17.17-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.11.4)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (4.9.0)
# Requirement already satisfied: urllib3>=1.26 in /opt/conda/lib/python3.10/site-packages (from great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.26.18)
# Collecting pyhopshive[thrift] (from hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading PyHopsHive-0.6.4.1.dev0.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyarrow>=10.0 in /opt/conda/lib/python3.10/site-packages (from hsfs[python]<3.8.0,>=3.7.0->hopsworks) (14.0.2)
# Collecting confluent-kafka<=2.3.0 (from hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading confluent_kafka-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting fastavro<=1.8.4,>=1.4.11 (from hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading fastavro-1.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->hopsworks) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->hopsworks) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->hopsworks) (2024.2.2)
# Collecting botocore<1.30.0,>=1.29.100 (from boto3->hopsworks)
#   Downloading botocore-1.29.165-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3->hopsworks) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from boto3->hopsworks) (0.6.2)
# Requirement already satisfied: six>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from furl->hopsworks) (1.16.0)
# Collecting orderedmultidict>=1.0.1 (from furl->hopsworks)
#   Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting javaobj-py3 (from pyjks->hopsworks)
#   Downloading javaobj_py3-0.4.4-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyasn1>=0.3.5 in /opt/conda/lib/python3.10/site-packages (from pyjks->hopsworks) (0.5.1)
# Requirement already satisfied: pyasn1-modules in /opt/conda/lib/python3.10/site-packages (from pyjks->hopsworks) (0.3.0)
# Collecting pycryptodomex (from pyjks->hopsworks)
#   Downloading pycryptodomex-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting twofish (from pyjks->hopsworks)
#   Downloading twofish-0.3.0.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas<2.2.0->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2023.4)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy<=1.4.48->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (3.0.3)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from pyhopshive[thrift]->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.0.0)
# Collecting thrift>=0.10.0 (from pyhopshive[thrift]->hsfs[python]<3.8.0,>=3.7.0->hopsworks)
#   Downloading thrift-0.20.0.tar.gz (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from altair<5.0.0,>=4.2.1->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.4)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.10/site-packages (from altair<5.0.0,>=4.2.1->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.12.1)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=3.2->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.16.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2.17.2)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (5.9.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (4.8.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (6.28.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2>=2.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.10/site-packages (from jsonpatch>=1.22->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2.4)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.16.2)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat>=5.0->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2.19.1)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.10/site-packages (from nbformat>=5.0->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (5.7.1)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (6.3.3)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (24.0.1)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (23.1.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /opt/conda/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (7.4.9)
# Requirement already satisfied: nbconvert>=5 in /opt/conda/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (6.4.5)
# Requirement already satisfied: nest-asyncio>=1.5 in /opt/conda/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.5.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.18.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.19.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic>=1.9.2->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic>=1.9.2->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2.14.6)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.2->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2.21)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.8.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (5.9.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->Ipython>=7.16.3->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core->nbformat>=5.0->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (3.11.0)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2.12.5)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.2.3)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.3.0)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (6.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.5.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.6.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (4.12.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.5.13)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->Ipython>=7.16.3->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->Ipython>=7.16.3->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.2.13)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->Ipython>=7.16.3->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->Ipython>=7.16.3->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->Ipython>=7.16.3->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (4.2.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.5.1)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (7.4.0)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.7.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2.5)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.3.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (0.1.1)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (20.11.0)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.18.12->hsfs<3.8.0,>=3.7.0->hsfs[python]<3.8.0,>=3.7.0->hopsworks) (2.8.19.20240106)
# Downloading pyhumps-1.6.1-py3-none-any.whl (5.0 kB)
# Downloading great_expectations-0.18.12-py3-none-any.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 33.5 MB/s eta 0:00:0000:0100:01
# Downloading furl-2.1.3-py2.py3-none-any.whl (20 kB)
# Downloading mock-5.1.0-py3-none-any.whl (30 kB)
# Downloading pyjks-20.0.0-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 3.7 MB/s eta 0:00:00
# Downloading botocore-1.29.165-py3-none-any.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 57.5 MB/s eta 0:00:0000:010:01m
# Downloading confluent_kafka-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 65.4 MB/s eta 0:00:00a 0:00:01
# Downloading fastavro-1.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 64.8 MB/s eta 0:00:00:00:01
# Downloading opensearch_py-2.4.2-py2.py3-none-any.whl (258 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.6/258.6 kB 20.1 MB/s eta 0:00:00
# Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl (11 kB)
# Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 53.0 MB/s eta 0:00:0000:0100:01
# Downloading SQLAlchemy-1.4.48-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.2 MB/s eta 0:00:00
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Downloading aiomysql-0.2.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 3.2 MB/s eta 0:00:00
# Downloading javaobj_py3-0.4.4-py2.py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 5.0 MB/s eta 0:00:00
# Downloading pycryptodomex-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 54.9 MB/s eta 0:00:0000:01
# Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.6/813.6 kB 38.8 MB/s eta 0:00:00
# Downloading makefun-1.15.2-py2.py3-none-any.whl (22 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.4 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.17.17-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 9.5 MB/s eta 0:00:00
# Building wheels for collected packages: hopsworks, hsfs, avro, hsml, twofish, thrift, pyhopshive
#   Building wheel for hopsworks (setup.py) ... done
#   Created wheel for hopsworks: filename=hopsworks-3.7.0-py3-none-any.whl size=84694 sha256=23b9933b88ce02a318304085abaf516e9141c8daa818ac96adbcf1813370063e
#   Stored in directory: /root/.cache/pip/wheels/4b/0f/5f/d1b716fcbe32887d3f44679a468680ea99d4119486cd9982f3
#   Building wheel for hsfs (setup.py) ... done
#   Created wheel for hsfs: filename=hsfs-3.7.6-py3-none-any.whl size=323587 sha256=c4eb5bfebb44a72807331d02576c6db9debd30b706a26a012da6f6fdd800d50f
#   Stored in directory: /root/.cache/pip/wheels/d7/5d/6a/45ca06f31f75a5e5a7ebed6ddd5806613f81000f00cab63a4d
#   Building wheel for avro (pyproject.toml) ... done
#   Created wheel for avro: filename=avro-1.11.3-py2.py3-none-any.whl size=123912 sha256=8bc61525b000e8e068dba87f5cebbd27aed56f3f9341c4a2623e17f67509eacc
#   Stored in directory: /root/.cache/pip/wheels/1d/f6/41/0e0399396af07060e64d4e32c8bd259b48b98a4a114df31294
#   Building wheel for hsml (setup.py) ... done
#   Created wheel for hsml: filename=hsml-3.7.1-py3-none-any.whl size=109360 sha256=bc1a9c77a543bd1fc62eb09372b764803dd81da19aac450e394ba596c1a3e9ef
#   Stored in directory: /root/.cache/pip/wheels/6e/4c/56/d3d3c99f1f2a3cab6e6010cf9dbf4980d508803e83c763d6f2
#   Building wheel for twofish (setup.py) ... done
#   Created wheel for twofish: filename=twofish-0.3.0-cp310-cp310-linux_x86_64.whl size=11087 sha256=2a68b73e808bc369f22a6b14c8471848709c0730bbc70e06b7b28106aaee80e0
#   Stored in directory: /root/.cache/pip/wheels/a7/3c/27/c390be4f3e8a299d4b2836f8daa19697eb991eacbfabe25031
#   Building wheel for thrift (setup.py) ... done
#   Created wheel for thrift: filename=thrift-0.20.0-cp310-cp310-linux_x86_64.whl size=185695 sha256=6cb3d527ae4f192c12d3cb6b9edd942344d9de20cb55e4ccb662fb7463c56e5c
#   Stored in directory: /root/.cache/pip/wheels/14/71/f9/849c9a9e9dbf246125223f9d12abc05fb72f56e7659c0dd5ff
#   Building wheel for pyhopshive (setup.py) ... done
#   Created wheel for pyhopshive: filename=PyHopsHive-0.6.4.1.dev0-py3-none-any.whl size=48564 sha256=2a0953b21e14994b8464ddc2891e81f0df0c6a736bd18945f11d97ac2b73d1bf
#   Stored in directory: /root/.cache/pip/wheels/2c/a5/da/3326e27d433d47029d233e314b993fdedb42b381650ea9dac7
# Successfully built hopsworks hsfs avro hsml twofish thrift pyhopshive
# Installing collected packages: twofish, pyhumps, makefun, javaobj-py3, confluent-kafka, tzlocal, thrift, sqlalchemy, ruamel.yaml, PyMySQL, pycryptodomex, orderedmultidict, mock, fastavro, avro, pyjks, pandas, opensearch-py, furl, botocore, aiomysql, pyhopshive, altair, hsml, great_expectations, hsfs, hopsworks
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.25
#     Uninstalling SQLAlchemy-2.0.25:
#       Successfully uninstalled SQLAlchemy-2.0.25
#   Attempting uninstall: ruamel.yaml
#     Found existing installation: ruamel.yaml 0.18.5
#     Uninstalling ruamel.yaml-0.18.5:
#       Successfully uninstalled ruamel.yaml-0.18.5
#   Attempting uninstall: fastavro
#     Found existing installation: fastavro 1.9.3
#     Uninstalling fastavro-1.9.3:
#       Successfully uninstalled fastavro-1.9.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.1
#     Uninstalling pandas-2.2.1:
#       Successfully uninstalled pandas-2.2.1
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.106
#     Uninstalling botocore-1.34.106:
#       Successfully uninstalled botocore-1.34.106
#   Attempting uninstall: altair
#     Found existing installation: altair 5.3.0
#     Uninstalling altair-5.3.0:
#       Successfully uninstalled altair-5.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.4.1 requires cubinlinker, which is not installed.
# cudf 24.4.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.4.1 requires ptxcompiler, which is not installed.
# cuml 24.4.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 24.4.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# aiobotocore 2.13.0 requires aiohttp<4.0.0,>=3.9.2, but you have aiohttp 3.9.1 which is incompatible.
# aiobotocore 2.13.0 requires botocore<1.34.107,>=1.34.70, but you have botocore 1.29.165 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 14.0.2 which is incompatible.
# beatrix-jupyterlab 2023.128.151533 requires jupyterlab~=3.6.0, but you have jupyterlab 4.2.1 which is incompatible.
# conda 24.5.0 requires packaging>=23.0, but you have packaging 21.3 which is incompatible.
# cudf 24.4.1 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.5.0 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.48 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.3 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# rapids-dask-dependency 24.4.1a0 requires dask==2024.1.1, but you have dask 2024.5.2 which is incompatible.
# rapids-dask-dependency 24.4.1a0 requires dask-expr==0.4.0, but you have dask-expr 1.1.2 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# xarray 2024.5.0 requires packaging>=23.1, but you have packaging 21.3 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed PyMySQL-1.1.1 aiomysql-0.2.0 altair-4.2.2 avro-1.11.3 botocore-1.29.165 confluent-kafka-2.3.0 fastavro-1.8.4 furl-2.1.3 great_expectations-0.18.12 hopsworks-3.7.0 hsfs-3.7.6 hsml-3.7.1 javaobj-py3-0.4.4 makefun-1.15.2 mock-5.1.0 opensearch-py-2.4.2 orderedmultidict-1.0.1 pandas-2.1.4 pycryptodomex-3.20.0 pyhopshive-0.6.4.1.dev0 pyhumps-1.6.1 pyjks-20.0.0 ruamel.yaml-0.17.17 sqlalchemy-1.4.48 thrift-0.20.0 twofish-0.3.0 tzlocal-5.2

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import hopsworks
import xgboost as xgb
import pandas as pd
import numpy as np
import os
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.model_selection import  train_test_split, RandomizedSearchCV
from sklearn.dummy import DummyClassifier
from sklearn.neural_network import MLPClassifier
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns
from hsml.model_schema import ModelSchema
from hsml.schema import Schema
import joblib

sns.set_palette('husl')
# %matplotlib inline

# %%
project = hopsworks.login()
# Out:
# Copy your Api Key (first register/login): https://c.app.hopsworks.ai/account/api/generated
# Paste it here:  ·················································································
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/809108

# %%
fs = project.get_feature_store()
heart_fg = fs.get_feature_group(name="heart",version=1)
# Out:
# Connected. Call `.close()` to terminate connection gracefully.

# %% [markdown]
# ## Get Data from feature store

# %%
query = heart_fg.select_all()
feature_view = fs.get_or_create_feature_view(name="heart",
                                             version=1,
                                            description="Read from Heart Dataset",
                                            labels=["heart_disease"],
                                            query=query)


X_train,X_test,y_train,y_test = feature_view.train_test_split(test_size=0.2)

X_train = X_train.drop(columns=['timestamp'])
X_test = X_test.drop(columns=['timestamp'])
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (15.45s)

# %% [markdown]
# ## Feature Pipeline

# %%
preprocessing_pipeline = joblib.load('/kaggle/input/heart-preprocessing-pipeline/preprocessing_pipeline_new.pkl')

# %%
X_train = preprocessing_pipeline.transform(X_train) 
X_test = preprocessing_pipeline.transform(X_test)

# %% [markdown]
# ## Handle Imbalance

# %%
heart_df_train = pd.DataFrame(y_train, columns=['heart_disease'])
sns.countplot(x='heart_disease',data=heart_df_train)
# Out:
# <Axes: xlabel='heart_disease', ylabel='count'>

# %%
ros = SMOTE(random_state=42)
X_train_res, y_train_res = ros.fit_resample(X_train,y_train)

# %%
heart_df_train_res = pd.DataFrame(y_train_res, columns=['heart_disease'])

# %%
sns.countplot(x='heart_disease', data=heart_df_train_res)
# Out:
# <Axes: xlabel='heart_disease', ylabel='count'>

# %% [markdown]
# ### Changing Dimension of Data to run on GPU

# %% [markdown]
# ## Train Models

# %%
base_model = DummyClassifier(strategy='most_frequent')
base_model.fit(X_train, y_train)
# Out:
# DummyClassifier(strategy='most_frequent')

# %%
default_rf = xgb.XGBClassifier(tree_method='gpu_hist', use_label_encoder=False, eval_metric='logloss')
default_rf.fit(X_train_res, y_train_res)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ### Random Search

# %% [markdown]
# # Save random search results to avoid re-running
# if not os.path.exists('train/rcv_data.pkl'):
#     model = RandomForestClassifier()
#     param_grid = {'n_estimators': [100, 150, 200],
#                 'max_features': ['sqrt', 'log2'],
#                 'max_depth': [None, 2, 5, 10],
#                 'min_samples_split': [2, 5, 10],
#                 'min_samples_leaf': [1, 2, 5, 10],
#                 'bootstrap': [True, False]}
#     rand_search = RandomizedSearchCV(model, param_grid, cv=3, scoring='f1_weighted', n_iter=100, random_state=42, n_jobs=2, verbose=True)
#     rand_search.fit(X_train_gpu, y_train_gpu)
#     joblib.dump(rand_search, 'train/rcv_data.pkl')
# else:
#     rand_search = joblib.load('train/rcv_data.pkl')
#
# print(f"Best params: {rand_search.best_params_}")
# print(f"Best score: {rand_search.best_score_}")
# best_model = rand_search.best_estimator_

# %%
# Define the parameter grid for random search specific to XGBClassifier
param_grid = {
    'n_estimators': [100, 150, 200],
    'max_depth': [None, 2, 5, 10],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'min_child_weight': [1, 2, 5]
}

os.makedirs('train', exist_ok=True)

# Check if the results file exists
if not os.path.exists('train/rcv_data.pkl'):
    # Initialize XGBClassifier with GPU support
    model = xgb.XGBClassifier(tree_method='gpu_hist', use_label_encoder=False, eval_metric='logloss', verbosity=0)

    # Set up RandomizedSearchCV
    rand_search = RandomizedSearchCV(model, param_grid, cv=3, scoring='f1_weighted', n_iter=100, random_state=42, n_jobs=2, verbose=True)
    
    # Perform random search
    rand_search.fit(X_train, y_train)  # Note: Use CPU-based data arrays for fitting
    
    # Save the random search results
    joblib.dump(rand_search, 'train/rcv_data.pkl')
else:
    # Load the random search results
    rand_search = joblib.load('train/rcv_data.pkl')

# Print the best parameters and best score
print(f"Best params: {rand_search.best_params_}")
print(f"Best score: {rand_search.best_score_}")

# Get the best model
best_model = rand_search.best_estimator_
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best params: {'subsample': 1.0, 'n_estimators': 150, 'min_child_weight': 1, 'max_depth': 10, 'learning_rate': 0.2, 'colsample_bytree': 1.0}
# Best score: 0.9053460493642103

# %% [markdown]
# ### MLPClassifier

# %%
if not os.path.exists('train/mlp_model.pkl'):
    mlp_model = MLPClassifier(hidden_layer_sizes=(100, 100, 100), max_iter=1000, verbose=True)
    mlp_model.fit(X_train, y_train)
    joblib.dump(mlp_model, 'train/mlp_model.pkl')
else:
    rand_search = joblib.load('train/mlp_model.pkl')
# Out:
# Iteration 1, loss = 0.24115504
# Iteration 2, loss = 0.23551560
# Iteration 3, loss = 0.23449585
# Iteration 4, loss = 0.23380628
# Iteration 5, loss = 0.23314991
# Iteration 6, loss = 0.23236445
# Iteration 7, loss = 0.23145570
# Iteration 8, loss = 0.23052436
# Iteration 9, loss = 0.22955958
# Iteration 10, loss = 0.22855613
# Iteration 11, loss = 0.22734911
# Iteration 12, loss = 0.22610737
# Iteration 13, loss = 0.22500723
# Iteration 14, loss = 0.22380660
# Iteration 15, loss = 0.22254098
# Iteration 16, loss = 0.22135685
# Iteration 17, loss = 0.22006141
# Iteration 18, loss = 0.21898768
# Iteration 19, loss = 0.21788711
# Iteration 20, loss = 0.21677168
# Iteration 21, loss = 0.21556922
# Iteration 22, loss = 0.21422409
# Iteration 23, loss = 0.21329902
# Iteration 24, loss = 0.21226373
# Iteration 25, loss = 0.21148670
# Iteration 26, loss = 0.21045820
# Iteration 27, loss = 0.20981828
# Iteration 28, loss = 0.20857287
# Iteration 29, loss = 0.20771602
# Iteration 30, loss = 0.20707346
# Iteration 31, loss = 0.20639343
# Iteration 32, loss = 0.20566952
# Iteration 33, loss = 0.20474169
# Iteration 34, loss = 0.20426776
# Iteration 35, loss = 0.20340647
# Iteration 36, loss = 0.20280601
# Iteration 37, loss = 0.20197085
# Iteration 38, loss = 0.20152306
# Iteration 39, loss = 0.20100035
# Iteration 40, loss = 0.20029098
# Iteration 41, loss = 0.19973317
# Iteration 42, loss = 0.19923991
# Iteration 43, loss = 0.19857314
# Iteration 44, loss = 0.19801770
# Iteration 45, loss = 0.19772152
# Iteration 46, loss = 0.19680646
# Iteration 47, loss = 0.19659724
# Iteration 48, loss = 0.19628972
# Iteration 49, loss = 0.19568224
# Iteration 50, loss = 0.19525437
# Iteration 51, loss = 0.19506382
# Iteration 52, loss = 0.19425372
# Iteration 53, loss = 0.19392402
# Iteration 54, loss = 0.19360327
# Iteration 55, loss = 0.19320667
# Iteration 56, loss = 0.19283091
# Iteration 57, loss = 0.19236153
# Iteration 58, loss = 0.19208908
# Iteration 59, loss = 0.19185782
# Iteration 60, loss = 0.19122187
# Iteration 61, loss = 0.19115150
# Iteration 62, loss = 0.19078209
# Iteration 63, loss = 0.19000377
# Iteration 64, loss = 0.18993131
# Iteration 65, loss = 0.18954448
# Iteration 66, loss = 0.18956604
# Iteration 67, loss = 0.18894554
# Iteration 68, loss = 0.18881901
# Iteration 69, loss = 0.18835900
# Iteration 70, loss = 0.18798978
# Iteration 71, loss = 0.18770430
# Iteration 72, loss = 0.18724029
# Iteration 73, loss = 0.18716630
# Iteration 74, loss = 0.18683412
# Iteration 75, loss = 0.18682577
# Iteration 76, loss = 0.18609420
# Iteration 77, loss = 0.18631432
# Iteration 78, loss = 0.18582773
# Iteration 79, loss = 0.18538198
# Iteration 80, loss = 0.18508277
# Iteration 81, loss = 0.18508305
# Iteration 82, loss = 0.18469023
# Iteration 83, loss = 0.18424941
# Iteration 84, loss = 0.18429647
# Iteration 85, loss = 0.18391592
# Iteration 86, loss = 0.18393488
# Iteration 87, loss = 0.18345970
# Iteration 88, loss = 0.18335150
# Iteration 89, loss = 0.18325022
# Iteration 90, loss = 0.18292859
# Iteration 91, loss = 0.18262902
# Iteration 92, loss = 0.18226750
# Iteration 93, loss = 0.18218105
# Iteration 94, loss = 0.18170476
# Iteration 95, loss = 0.18165314
# Iteration 96, loss = 0.18147768
# Iteration 97, loss = 0.18164492
# Iteration 98, loss = 0.18121034
# Iteration 99, loss = 0.18070476
# Iteration 100, loss = 0.18096331
# Iteration 101, loss = 0.18063141
# Iteration 102, loss = 0.18028475
# Iteration 103, loss = 0.18043897
# Iteration 104, loss = 0.18021130
# Iteration 105, loss = 0.18033464
# Iteration 106, loss = 0.17962914
# Iteration 107, loss = 0.17956689
# Iteration 108, loss = 0.17927348
# Iteration 109, loss = 0.17918645
# Iteration 110, loss = 0.17868330
# Iteration 111, loss = 0.17927147
# Iteration 112, loss = 0.17845795
# Iteration 113, loss = 0.17864296
# Iteration 114, loss = 0.17849525
# Iteration 115, loss = 0.17803126
# Iteration 116, loss = 0.17826729
# Iteration 117, loss = 0.17801862
# Iteration 118, loss = 0.17770343
# Iteration 119, loss = 0.17800290
# Iteration 120, loss = 0.17743223
# Iteration 121, loss = 0.17712053
# Iteration 122, loss = 0.17726496
# Iteration 123, loss = 0.17724882

# %% [markdown]
# ### Testing all models

# %%
def test_model(model, X_test, y_test, name='Model'):
    y_pred = model.predict(X_test)
    report = classification_report(y_test, y_pred)

    print(f"---- Results for {name} ----")
    print(report)
    print(f"SCORE (f1_weighted): {f1_score(y_test, y_pred, average='weighted')}\n\n")

test_model(base_model, X_test, y_test, name='Dummy (Baseline)')
test_model(default_rf, X_test, y_test, name='Random Forest')
test_model(mlp_model, X_test, y_test, name='MLP')
test_model(best_model, X_test, y_test, name='Random Forest (Optimized)')
# Out:
# ---- Results for Dummy (Baseline) ----
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95    109735
#          1.0       0.00      0.00      0.00     10952
#
#     accuracy                           0.91    120687
#    macro avg       0.45      0.50      0.48    120687
# weighted avg       0.83      0.91      0.87    120687
#
# SCORE (f1_weighted): 0.8660359051614009
#
#
# ---- Results for Random Forest ----
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.89      0.92    109735
#          1.0       0.31      0.49      0.38     10952
#
#     accuracy                           0.85    120687
#    macro avg       0.63      0.69      0.65    120687
# weighted avg       0.89      0.85      0.87    120687
#
# SCORE (f1_weighted): 0.8686509237493185
#
#
# ---- Results for MLP ----
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.98      0.96    109735
#          1.0       0.62      0.29      0.40     10952
#
#     accuracy                           0.92    120687
#    macro avg       0.77      0.64      0.68    120687
# weighted avg       0.90      0.92      0.91    120687
#
# SCORE (f1_weighted): 0.9058978822246904
#
#
# ---- Results for Random Forest (Optimized) ----
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.99      0.96    109735
#          1.0       0.81      0.24      0.37     10952
#
#     accuracy                           0.93    120687
#    macro avg       0.87      0.62      0.66    120687
# weighted avg       0.92      0.93      0.91    120687
#
# SCORE (f1_weighted): 0.9066105223624363

# %% [markdown]
# ### Training Best model

# %%
best_model = xgb.XGBClassifier(tree_method='gpu_hist',n_estimators=200, min_samples_split=5, min_samples_leaf=2, max_features='sqrt', max_depth=10, bootstrap=False)
best_model.fit(X_train_res, y_train_res)
# Out:
# XGBClassifier(base_score=None, booster=None, bootstrap=False, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_features='sqrt',
#               max_leaves=None, min_child_weight=None, min_samples_leaf=2,
#               min_samples_split=5, missing=nan, monotone_constraints=None,
#               multi_strategy=None, ...)

# %% [markdown]
# ### Uploading model to feature store

# %%
# We will now upload our model to the Hopsworks Model Registry. First get an object for the model registry.
mr = project.get_model_registry()

# The contents of the 'iris_model' directory will be saved to the model registry. Create the dir, first.
model_dir="heart_model"
os.makedirs(model_dir, exist_ok=True)

# Save both our model and the confusion matrix to 'model_dir', whose contents will be uploaded to the model registry
joblib.dump(best_model, model_dir + "/heart_model.pkl")
# Already stored in the feature extraction
joblib.dump(preprocessing_pipeline, model_dir + "/preprocessing_pipeline.pkl")


# Specify the schema of the model's input/output using the features (X_train) and labels (y_train)
input_schema = Schema(X_train)
output_schema = Schema(y_train)
model_schema = ModelSchema(input_schema, output_schema)

# Create an entry in the model registry that includes the model's name, desc, metrics
heart_model = mr.python.create_model(
    version=1.1,
    name="heart_model_v1", 
    model_schema=model_schema,
    description="Heart Predictor"
)

# Upload the model to the model registry, including all files in 'model_dir'
heart_model.save(model_dir)
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
#   0%|          | 0/6 [00:00<?, ?it/s]
# Uploading: 0.000%|          | 0/9975 elapsed<00:00 remaining<?
# Uploading: 0.000%|          | 0/4889186 elapsed<00:00 remaining<?
# Uploading: 0.000%|          | 0/243 elapsed<00:00 remaining<?
# Model created, explore it at https://c.app.hopsworks.ai:443/p/809108/models/heart_model_v1/1
# Model(name: 'heart_model_v1', version: 1)
